# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2ae34bd2-82af-4566-b15d-7086dc7a6fc5" name="files[]" multiple disabled />
#      <output id="result-2ae34bd2-82af-4566-b15d-7086dc7a6fc5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"heshamahmed","key":"c6e04a23febb9a9518961ff362b73c9a"}'}

# %%
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 67 May  8 02:36 kaggle.json

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d kmader/skin-cancer-mnist-ham10000
# Out:
# Downloading skin-cancer-mnist-ham10000.zip to /content
# 100% 5.20G/5.20G [02:08<00:00, 94.4MB/s]
# 100% 5.20G/5.20G [02:08<00:00, 43.3MB/s]

# %%
# !kaggle datasets download -d kmader/skin-cancer-mnist-ham10000
# Out:
# skin-cancer-mnist-ham10000.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip \*.zip

# %%
from numpy.random import seed
seed(101)
import tensorflow
tensorflow.random.set_seed(101)

import cv2
import pandas as pd
import numpy as np
#import keras
#from keras import backend as K
from tqdm import tqdm
from glob import glob

import tensorflow
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

import os

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import itertools
import shutil
import matplotlib.pyplot as plt
# %matplotlib inline

# pytorch libraries
import torch
from torch import optim,nn
from torch.autograd import Variable
from torch.utils.data import DataLoader,Dataset
from torchvision import models,transforms

# %%
# Create a new directory
base_dir = 'base_dir'
os.mkdir(base_dir)


#[CREATE FOLDERS INSIDE THE BASE DIRECTORY]

# now we create 7 folders inside 'base_dir':

# train_dir
    # nv
    # mel
    # bkl
    # bcc
    # akiec
    # vasc
    # df
 
# val_dir
    # nv
    # mel
    # bkl
    # bcc
    # akiec
    # vasc
    # df

# create a path to 'base_dir' to which we will join the names of the new folders
# train_dir
train_dir = os.path.join(base_dir, 'train_dir')
os.mkdir(train_dir)

# val_dir
val_dir = os.path.join(base_dir, 'val_dir')
os.mkdir(val_dir)


# [CREATE FOLDERS INSIDE THE TRAIN, VALIDATION AND TEST FOLDERS]
# Inside each folder we create seperate folders for each class

# create new folders inside train_dir
nv = os.path.join(train_dir, 'nv')
os.mkdir(nv)
mel = os.path.join(train_dir, 'mel')
os.mkdir(mel)
bkl = os.path.join(train_dir, 'bkl')
os.mkdir(bkl)
bcc = os.path.join(train_dir, 'bcc')
os.mkdir(bcc)
akiec = os.path.join(train_dir, 'akiec')
os.mkdir(akiec)
vasc = os.path.join(train_dir, 'vasc')
os.mkdir(vasc)
df = os.path.join(train_dir, 'df')
os.mkdir(df)



# create new folders inside val_dir
nv = os.path.join(val_dir, 'nv')
os.mkdir(nv)
mel = os.path.join(val_dir, 'mel')
os.mkdir(mel)
bkl = os.path.join(val_dir, 'bkl')
os.mkdir(bkl)
bcc = os.path.join(val_dir, 'bcc')
os.mkdir(bcc)
akiec = os.path.join(val_dir, 'akiec')
os.mkdir(akiec)
vasc = os.path.join(val_dir, 'vasc')
os.mkdir(vasc)
df = os.path.join(val_dir, 'df')
os.mkdir(df)

# %%
os.listdir('base_dir/train_dir')
# Out:
# ['bcc', 'vasc', 'bkl', 'mel', 'akiec', 'nv', 'df']

# %%
df_data = pd.read_csv('HAM10000_metadata.csv')

df_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
# this will tell us how many images are associated with each lesion_id
df = df_data.groupby('lesion_id').count()

# now we filter out lesion_id's that have only one image associated with it
df = df[df['image_id'] == 1]

df.reset_index(inplace=True)

df.head()
# Out:
#      lesion_id  image_id  dx  dx_type  age  sex  localization
# 0  HAM_0000001         1   1        1    1    1             1
# 1  HAM_0000003         1   1        1    1    1             1
# 2  HAM_0000004         1   1        1    1    1             1
# 3  HAM_0000007         1   1        1    1    1             1
# 4  HAM_0000008         1   1        1    1    1             1

# %%
# here we identify lesion_id's that have duplicate images and those that have only
# one image.

def identify_duplicates(x):
    
    unique_list = list(df['lesion_id'])
    
    if x in unique_list:
        return 'no_duplicates'
    else:
        return 'has_duplicates'
    
# create a new colum that is a copy of the lesion_id column
df_data['duplicates'] = df_data['lesion_id']
# apply the function to this new column
df_data['duplicates'] = df_data['duplicates'].apply(identify_duplicates)

df_data.head()
# Out:
#      lesion_id      image_id   dx  ...   sex  localization      duplicates
# 0  HAM_0000118  ISIC_0027419  bkl  ...  male         scalp  has_duplicates
# 1  HAM_0000118  ISIC_0025030  bkl  ...  male         scalp  has_duplicates
# 2  HAM_0002730  ISIC_0026769  bkl  ...  male         scalp  has_duplicates
# 3  HAM_0002730  ISIC_0025661  bkl  ...  male         scalp  has_duplicates
# 4  HAM_0001466  ISIC_0031633  bkl  ...  male           ear  has_duplicates
#
# [5 rows x 8 columns]

# %%
df_data['duplicates'].value_counts()
# Out:
# no_duplicates     5514
# has_duplicates    4501
# Name: duplicates, dtype: int64

# %%
# now we filter out images that don't have duplicates
df = df_data[df_data['duplicates'] == 'no_duplicates']

df.shape
# Out:
# (5514, 8)

# %%
# now we create a val set using df because we are sure that none of these images
# have augmented duplicates in the train set
y = df['dx']

_, df_val = train_test_split(df, test_size=0.17, random_state=101, stratify=y)

df_val.shape
# Out:
# (938, 8)

# %%
df_val['dx'].value_counts()
# Out:
# nv       751
# bkl       75
# mel       39
# bcc       30
# akiec     26
# vasc      11
# df         6
# Name: dx, dtype: int64

# %%
# This function identifies if an image is part of the train
# or val set.
def identify_val_rows(x):
    # create a list of all the lesion_id's in the val set
    val_list = list(df_val['image_id'])
    
    if str(x) in val_list:
        return 'val'
    else:
        return 'train'

# identify train and val rows

# create a new colum that is a copy of the image_id column
df_data['train_or_val'] = df_data['image_id']
# apply the function to this new column
df_data['train_or_val'] = df_data['train_or_val'].apply(identify_val_rows)
   
# filter out train rows
df_train = df_data[df_data['train_or_val'] == 'train']


print(len(df_train))
print(len(df_val))
# Out:
# 9077
# 938

# %%
df_train['dx'].value_counts()
# Out:
# nv       5954
# mel      1074
# bkl      1024
# bcc       484
# akiec     301
# vasc      131
# df        109
# Name: dx, dtype: int64

# %%
df_val['dx'].value_counts()
# Out:
# nv       751
# bkl       75
# mel       39
# bcc       30
# akiec     26
# vasc      11
# df         6
# Name: dx, dtype: int64

# %%
# Set the image_id as the index in df_data
df_data.set_index('image_id', inplace=True)

# %%
folder_1 = os.listdir('ham10000_images_part_1')
folder_2 = os.listdir('ham10000_images_part_2')

# Get a list of train and val images
train_list = list(df_train['image_id'])
val_list = list(df_val['image_id'])



# Transfer the train images

for image in train_list:
    
    fname = image + '.jpg'
    label = df_data.loc[image,'dx']
    
    if fname in folder_1:
        # source path to image
        src = os.path.join('ham10000_images_part_1', fname)
        # destination path to image
        dst = os.path.join(train_dir, label, fname)
        # copy the image from the source to the destination
        shutil.copyfile(src, dst)

    if fname in folder_2:
        # source path to image
        src = os.path.join('ham10000_images_part_2', fname)
        # destination path to image
        dst = os.path.join(train_dir, label, fname)
        # copy the image from the source to the destination
        shutil.copyfile(src, dst)


# Transfer the val images

for image in val_list:
    
    fname = image + '.jpg'
    label = df_data.loc[image,'dx']
    
    if fname in folder_1:
        # source path to image
        src = os.path.join('ham10000_images_part_1', fname)
        # destination path to image
        dst = os.path.join(val_dir, label, fname)
        # copy the image from the source to the destination
        shutil.copyfile(src, dst)

    if fname in folder_2:
        # source path to image
        src = os.path.join('ham10000_images_part_2', fname)
        # destination path to image
        dst = os.path.join(val_dir, label, fname)
        # copy the image from the source to the destination
        shutil.copyfile(src, dst)

# %%
class_list = ['mel','bkl','bcc','akiec','vasc','df']

for item in class_list:
    
    # We are creating temporary directories here because we delete these directories later
    # create a base dir
    aug_dir = 'aug_dir'
    os.mkdir(aug_dir)
    # create a dir within the base dir to store images of the same class
    img_dir = os.path.join(aug_dir, 'img_dir')
    os.mkdir(img_dir)

    # Choose a class
    img_class = item

    # list all images in that directory
    img_list = os.listdir('base_dir/train_dir/' + img_class)

    # Copy images from the class train dir to the img_dir e.g. class 'mel'
    for fname in img_list:
            # source path to image
            src = os.path.join('base_dir/train_dir/' + img_class, fname)
            # destination path to image
            dst = os.path.join(img_dir, fname)
            # copy the image from the source to the destination
            shutil.copyfile(src, dst)


    # point to a dir containing the images and not to the images themselves
    path = aug_dir
    save_path = 'base_dir/train_dir/' + img_class

    # Create a data generator
    datagen = ImageDataGenerator(
        rotation_range=180,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        vertical_flip=True,
        #brightness_range=(0.9,1.1),
        fill_mode='nearest')

    batch_size = 50

    aug_datagen = datagen.flow_from_directory(path,
                                           save_to_dir=save_path,
                                           save_format='jpg',
                                                    target_size=(224,224),
                                                    batch_size=batch_size)



    # Generate the augmented images and add them to the training folders
    
    ###########
    
    num_aug_images_wanted = 6000 # total number of images we want to have in each class
    
    ###########
    
    num_files = len(os.listdir(img_dir))
    num_batches = int(np.ceil((num_aug_images_wanted-num_files)/batch_size))

    # run the generator and create about 6000 augmented images
    for i in range(0,num_batches):

        imgs, labels = next(aug_datagen)
        
    # delete temporary directory with the raw image files
    shutil.rmtree('aug_dir')
# Out:
# Found 1074 images belonging to 1 classes.
# Found 1024 images belonging to 1 classes.
# Found 484 images belonging to 1 classes.
# Found 301 images belonging to 1 classes.
# Found 131 images belonging to 1 classes.
# Found 109 images belonging to 1 classes.

# %%
def plots(ims, figsize=(12,6), rows=5, interp=False, titles=None): # 12,6
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(len(ims)):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i], interpolation=None if interp else 'none')
        
plots(imgs, titles=None) # titles=labels will display the image labels

# %%
train_path = 'base_dir/train_dir'
valid_path = 'base_dir/val_dir'

num_train_samples = len(df_train)
num_val_samples = len(df_val)
train_batch_size = 10
val_batch_size = 10
image_size = 224

train_steps = np.ceil(num_train_samples / train_batch_size)
val_steps = np.ceil(num_val_samples / val_batch_size)

# %%
datagen = ImageDataGenerator(
    preprocessing_function= \
    tensorflow.keras.applications.mobilenet.preprocess_input)

train_batches = datagen.flow_from_directory(train_path,
                                            target_size=(image_size,image_size),
                                            batch_size=train_batch_size)

valid_batches = datagen.flow_from_directory(valid_path,
                                            target_size=(image_size,image_size),
                                            batch_size=val_batch_size)

# Note: shuffle=False causes the test dataset to not be shuffled
test_batches = datagen.flow_from_directory(valid_path,
                                            target_size=(image_size,image_size),
                                            batch_size=1,
                                            shuffle=False)
# Out:
# Found 38569 images belonging to 7 classes.
# Found 938 images belonging to 7 classes.
# Found 938 images belonging to 7 classes.

# %%
# create a copy of a mobilenet model

mobile = tensorflow.keras.applications.mobilenet.MobileNet()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
# 17227776/17225924 [==============================] - 0s 0us/step

# %%
x = mobile.layers[-6].output

# Create a new dense layer for predictions
# 7 corresponds to the number of classes
x = Dropout(0.25)(x)
predictions = Dense(7, activation='softmax')(x)

# inputs=mobile.input selects the input layer, outputs=predictions refers to the
# dense layer we created above.

model = Model(inputs=mobile.input, outputs=predictions)

# %%
for layer in model.layers[:-23]:
    layer.trainable = False

# %%
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy

def top_3_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

def top_2_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=2)

# %%
model.compile(Adam(lr=0.01), loss='categorical_crossentropy', 
              metrics=[categorical_accuracy, top_2_accuracy, top_3_accuracy])

# %%
# Get the labels that are associated with each index
print(valid_batches.class_indices)
# Out:
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
# Add weights to try to make the model more sensitive to melanoma

class_weights={
    0: 1.0, # akiec
    1: 1.0, # bcc
    2: 1.0, # bkl
    3: 1.0, # df
    4: 3.0, # mel # Try to make the model more sensitive to Melanoma.
    5: 1.0, # nv
    6: 1.0, # vasc
}

# %%
filepath = "content/drive/mobilenet.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_top_3_accuracy', verbose=1, 
                             save_best_only=True, mode='max')

reduce_lr = ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.5, patience=2, 
                                   verbose=1, mode='max', min_lr=0.00001)
                              
                              
callbacks_list = [checkpoint, reduce_lr]

history = model.fit_generator(train_batches, steps_per_epoch=train_steps, 
                              class_weight=class_weights,
                    validation_data=valid_batches,
                    validation_steps=val_steps,
                    epochs=30, verbose=1,
                   callbacks=callbacks_list)
# Out:
# Epoch 1/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2188 - categorical_accuracy: 0.9332 - top_2_accuracy: 0.9903 - top_3_accuracy: 0.9986
# Epoch 00001: val_top_3_accuracy improved from -inf to 0.98294, saving model to content/drive/mobilenet.h5
# 908/908 [==============================] - 47s 51ms/step - loss: 0.2186 - categorical_accuracy: 0.9333 - top_2_accuracy: 0.9903 - top_3_accuracy: 0.9986 - val_loss: 0.3548 - val_categorical_accuracy: 0.8913 - val_top_2_accuracy: 0.9563 - val_top_3_accuracy: 0.9829 - lr: 1.0000e-05
# Epoch 2/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2229 - categorical_accuracy: 0.9295 - top_2_accuracy: 0.9899 - top_3_accuracy: 0.9981
# Epoch 00002: val_top_3_accuracy improved from 0.98294 to 0.98721, saving model to content/drive/mobilenet.h5
# 908/908 [==============================] - 46s 51ms/step - loss: 0.2229 - categorical_accuracy: 0.9295 - top_2_accuracy: 0.9899 - top_3_accuracy: 0.9981 - val_loss: 0.3640 - val_categorical_accuracy: 0.8870 - val_top_2_accuracy: 0.9606 - val_top_3_accuracy: 0.9872 - lr: 1.0000e-05
# Epoch 3/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2078 - categorical_accuracy: 0.9338 - top_2_accuracy: 0.9899 - top_3_accuracy: 0.9992
# Epoch 00003: val_top_3_accuracy did not improve from 0.98721
# 908/908 [==============================] - 46s 51ms/step - loss: 0.2078 - categorical_accuracy: 0.9338 - top_2_accuracy: 0.9899 - top_3_accuracy: 0.9992 - val_loss: 0.4031 - val_categorical_accuracy: 0.8753 - val_top_2_accuracy: 0.9520 - val_top_3_accuracy: 0.9797 - lr: 1.0000e-05
# Epoch 4/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2063 - categorical_accuracy: 0.9362 - top_2_accuracy: 0.9911 - top_3_accuracy: 0.9985
# Epoch 00004: val_top_3_accuracy improved from 0.98721 to 0.98827, saving model to content/drive/mobilenet.h5
# 908/908 [==============================] - 46s 51ms/step - loss: 0.2063 - categorical_accuracy: 0.9362 - top_2_accuracy: 0.9911 - top_3_accuracy: 0.9985 - val_loss: 0.3378 - val_categorical_accuracy: 0.8955 - val_top_2_accuracy: 0.9584 - val_top_3_accuracy: 0.9883 - lr: 1.0000e-05
# Epoch 5/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2218 - categorical_accuracy: 0.9333 - top_2_accuracy: 0.9920 - top_3_accuracy: 0.9988
# Epoch 00005: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 51ms/step - loss: 0.2218 - categorical_accuracy: 0.9333 - top_2_accuracy: 0.9920 - top_3_accuracy: 0.9988 - val_loss: 0.3713 - val_categorical_accuracy: 0.8817 - val_top_2_accuracy: 0.9574 - val_top_3_accuracy: 0.9819 - lr: 1.0000e-05
# Epoch 6/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2083 - categorical_accuracy: 0.9352 - top_2_accuracy: 0.9907 - top_3_accuracy: 0.9988
# Epoch 00006: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2081 - categorical_accuracy: 0.9352 - top_2_accuracy: 0.9907 - top_3_accuracy: 0.9988 - val_loss: 0.3387 - val_categorical_accuracy: 0.8998 - val_top_2_accuracy: 0.9563 - val_top_3_accuracy: 0.9840 - lr: 1.0000e-05
# Epoch 7/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2140 - categorical_accuracy: 0.9325 - top_2_accuracy: 0.9913 - top_3_accuracy: 0.9991
# Epoch 00007: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2140 - categorical_accuracy: 0.9325 - top_2_accuracy: 0.9913 - top_3_accuracy: 0.9991 - val_loss: 0.3667 - val_categorical_accuracy: 0.8859 - val_top_2_accuracy: 0.9584 - val_top_3_accuracy: 0.9851 - lr: 1.0000e-05
# Epoch 8/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2323 - categorical_accuracy: 0.9322 - top_2_accuracy: 0.9882 - top_3_accuracy: 0.9988
# Epoch 00008: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 48s 52ms/step - loss: 0.2321 - categorical_accuracy: 0.9323 - top_2_accuracy: 0.9882 - top_3_accuracy: 0.9988 - val_loss: 0.3576 - val_categorical_accuracy: 0.8827 - val_top_2_accuracy: 0.9595 - val_top_3_accuracy: 0.9851 - lr: 1.0000e-05
# Epoch 9/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2158 - categorical_accuracy: 0.9340 - top_2_accuracy: 0.9900 - top_3_accuracy: 0.9982
# Epoch 00009: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2158 - categorical_accuracy: 0.9340 - top_2_accuracy: 0.9900 - top_3_accuracy: 0.9982 - val_loss: 0.3798 - val_categorical_accuracy: 0.8827 - val_top_2_accuracy: 0.9606 - val_top_3_accuracy: 0.9883 - lr: 1.0000e-05
# Epoch 10/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2152 - categorical_accuracy: 0.9302 - top_2_accuracy: 0.9903 - top_3_accuracy: 0.9993
# Epoch 00010: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2154 - categorical_accuracy: 0.9303 - top_2_accuracy: 0.9903 - top_3_accuracy: 0.9993 - val_loss: 0.3463 - val_categorical_accuracy: 0.8891 - val_top_2_accuracy: 0.9563 - val_top_3_accuracy: 0.9819 - lr: 1.0000e-05
# Epoch 11/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2160 - categorical_accuracy: 0.9316 - top_2_accuracy: 0.9886 - top_3_accuracy: 0.9987
# Epoch 00011: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2162 - categorical_accuracy: 0.9316 - top_2_accuracy: 0.9885 - top_3_accuracy: 0.9987 - val_loss: 0.3394 - val_categorical_accuracy: 0.8945 - val_top_2_accuracy: 0.9574 - val_top_3_accuracy: 0.9872 - lr: 1.0000e-05
# Epoch 12/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2138 - categorical_accuracy: 0.9333 - top_2_accuracy: 0.9901 - top_3_accuracy: 0.9982
# Epoch 00012: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2136 - categorical_accuracy: 0.9334 - top_2_accuracy: 0.9901 - top_3_accuracy: 0.9982 - val_loss: 0.3772 - val_categorical_accuracy: 0.8827 - val_top_2_accuracy: 0.9531 - val_top_3_accuracy: 0.9819 - lr: 1.0000e-05
# Epoch 13/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2159 - categorical_accuracy: 0.9358 - top_2_accuracy: 0.9905 - top_3_accuracy: 0.9987
# Epoch 00013: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 51ms/step - loss: 0.2159 - categorical_accuracy: 0.9358 - top_2_accuracy: 0.9905 - top_3_accuracy: 0.9987 - val_loss: 0.3488 - val_categorical_accuracy: 0.8923 - val_top_2_accuracy: 0.9595 - val_top_3_accuracy: 0.9861 - lr: 1.0000e-05
# Epoch 14/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2176 - categorical_accuracy: 0.9316 - top_2_accuracy: 0.9892 - top_3_accuracy: 0.9989
# Epoch 00014: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2176 - categorical_accuracy: 0.9316 - top_2_accuracy: 0.9892 - top_3_accuracy: 0.9989 - val_loss: 0.3454 - val_categorical_accuracy: 0.8998 - val_top_2_accuracy: 0.9638 - val_top_3_accuracy: 0.9872 - lr: 1.0000e-05
# Epoch 15/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2112 - categorical_accuracy: 0.9367 - top_2_accuracy: 0.9915 - top_3_accuracy: 0.9992
# Epoch 00015: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 51ms/step - loss: 0.2113 - categorical_accuracy: 0.9366 - top_2_accuracy: 0.9914 - top_3_accuracy: 0.9992 - val_loss: 0.3979 - val_categorical_accuracy: 0.8817 - val_top_2_accuracy: 0.9499 - val_top_3_accuracy: 0.9819 - lr: 1.0000e-05
# Epoch 16/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2191 - categorical_accuracy: 0.9340 - top_2_accuracy: 0.9884 - top_3_accuracy: 0.9990
# Epoch 00016: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2188 - categorical_accuracy: 0.9340 - top_2_accuracy: 0.9884 - top_3_accuracy: 0.9990 - val_loss: 0.3443 - val_categorical_accuracy: 0.8891 - val_top_2_accuracy: 0.9584 - val_top_3_accuracy: 0.9829 - lr: 1.0000e-05
# Epoch 17/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2180 - categorical_accuracy: 0.9319 - top_2_accuracy: 0.9893 - top_3_accuracy: 0.9978
# Epoch 00017: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 48s 52ms/step - loss: 0.2178 - categorical_accuracy: 0.9319 - top_2_accuracy: 0.9893 - top_3_accuracy: 0.9978 - val_loss: 0.3710 - val_categorical_accuracy: 0.8902 - val_top_2_accuracy: 0.9574 - val_top_3_accuracy: 0.9829 - lr: 1.0000e-05
# Epoch 18/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2198 - categorical_accuracy: 0.9291 - top_2_accuracy: 0.9906 - top_3_accuracy: 0.9991
# Epoch 00018: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 46s 51ms/step - loss: 0.2198 - categorical_accuracy: 0.9291 - top_2_accuracy: 0.9906 - top_3_accuracy: 0.9991 - val_loss: 0.3294 - val_categorical_accuracy: 0.8913 - val_top_2_accuracy: 0.9627 - val_top_3_accuracy: 0.9861 - lr: 1.0000e-05
# Epoch 19/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2119 - categorical_accuracy: 0.9315 - top_2_accuracy: 0.9915 - top_3_accuracy: 0.9987
# Epoch 00019: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 51ms/step - loss: 0.2125 - categorical_accuracy: 0.9314 - top_2_accuracy: 0.9915 - top_3_accuracy: 0.9987 - val_loss: 0.3707 - val_categorical_accuracy: 0.8902 - val_top_2_accuracy: 0.9552 - val_top_3_accuracy: 0.9829 - lr: 1.0000e-05
# Epoch 20/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2171 - categorical_accuracy: 0.9323 - top_2_accuracy: 0.9898 - top_3_accuracy: 0.9988
# Epoch 00020: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2171 - categorical_accuracy: 0.9323 - top_2_accuracy: 0.9898 - top_3_accuracy: 0.9988 - val_loss: 0.3395 - val_categorical_accuracy: 0.8923 - val_top_2_accuracy: 0.9563 - val_top_3_accuracy: 0.9851 - lr: 1.0000e-05
# Epoch 21/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2189 - categorical_accuracy: 0.9328 - top_2_accuracy: 0.9871 - top_3_accuracy: 0.9992
# Epoch 00021: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 48s 52ms/step - loss: 0.2189 - categorical_accuracy: 0.9328 - top_2_accuracy: 0.9871 - top_3_accuracy: 0.9992 - val_loss: 0.3830 - val_categorical_accuracy: 0.8817 - val_top_2_accuracy: 0.9574 - val_top_3_accuracy: 0.9819 - lr: 1.0000e-05
# Epoch 22/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2158 - categorical_accuracy: 0.9343 - top_2_accuracy: 0.9898 - top_3_accuracy: 0.9982
# Epoch 00022: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2158 - categorical_accuracy: 0.9343 - top_2_accuracy: 0.9898 - top_3_accuracy: 0.9982 - val_loss: 0.3612 - val_categorical_accuracy: 0.8870 - val_top_2_accuracy: 0.9595 - val_top_3_accuracy: 0.9861 - lr: 1.0000e-05
# Epoch 23/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2119 - categorical_accuracy: 0.9322 - top_2_accuracy: 0.9915 - top_3_accuracy: 0.9990
# Epoch 00023: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 46s 51ms/step - loss: 0.2123 - categorical_accuracy: 0.9322 - top_2_accuracy: 0.9914 - top_3_accuracy: 0.9990 - val_loss: 0.3458 - val_categorical_accuracy: 0.8891 - val_top_2_accuracy: 0.9595 - val_top_3_accuracy: 0.9829 - lr: 1.0000e-05
# Epoch 24/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2134 - categorical_accuracy: 0.9362 - top_2_accuracy: 0.9901 - top_3_accuracy: 0.9990
# Epoch 00024: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2134 - categorical_accuracy: 0.9362 - top_2_accuracy: 0.9901 - top_3_accuracy: 0.9990 - val_loss: 0.3617 - val_categorical_accuracy: 0.8870 - val_top_2_accuracy: 0.9574 - val_top_3_accuracy: 0.9829 - lr: 1.0000e-05
# Epoch 25/30
# 906/908 [============================>.] - ETA: 0s - loss: 0.2095 - categorical_accuracy: 0.9326 - top_2_accuracy: 0.9893 - top_3_accuracy: 0.9991
# Epoch 00025: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 51ms/step - loss: 0.2091 - categorical_accuracy: 0.9327 - top_2_accuracy: 0.9893 - top_3_accuracy: 0.9991 - val_loss: 0.3397 - val_categorical_accuracy: 0.8891 - val_top_2_accuracy: 0.9584 - val_top_3_accuracy: 0.9872 - lr: 1.0000e-05
# Epoch 26/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2134 - categorical_accuracy: 0.9346 - top_2_accuracy: 0.9916 - top_3_accuracy: 0.9988
# Epoch 00026: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 46s 51ms/step - loss: 0.2134 - categorical_accuracy: 0.9346 - top_2_accuracy: 0.9916 - top_3_accuracy: 0.9988 - val_loss: 0.3984 - val_categorical_accuracy: 0.8817 - val_top_2_accuracy: 0.9520 - val_top_3_accuracy: 0.9808 - lr: 1.0000e-05
# Epoch 27/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2270 - categorical_accuracy: 0.9261 - top_2_accuracy: 0.9907 - top_3_accuracy: 0.9989
# Epoch 00027: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 51ms/step - loss: 0.2270 - categorical_accuracy: 0.9261 - top_2_accuracy: 0.9907 - top_3_accuracy: 0.9989 - val_loss: 0.3475 - val_categorical_accuracy: 0.8902 - val_top_2_accuracy: 0.9616 - val_top_3_accuracy: 0.9883 - lr: 1.0000e-05
# Epoch 28/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2140 - categorical_accuracy: 0.9348 - top_2_accuracy: 0.9894 - top_3_accuracy: 0.9987
# Epoch 00028: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 47s 52ms/step - loss: 0.2140 - categorical_accuracy: 0.9348 - top_2_accuracy: 0.9894 - top_3_accuracy: 0.9987 - val_loss: 0.3720 - val_categorical_accuracy: 0.8902 - val_top_2_accuracy: 0.9584 - val_top_3_accuracy: 0.9829 - lr: 1.0000e-05
# Epoch 29/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.2062 - categorical_accuracy: 0.9340 - top_2_accuracy: 0.9908 - top_3_accuracy: 0.9988
# Epoch 00029: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 46s 51ms/step - loss: 0.2062 - categorical_accuracy: 0.9340 - top_2_accuracy: 0.9909 - top_3_accuracy: 0.9988 - val_loss: 0.3597 - val_categorical_accuracy: 0.8870 - val_top_2_accuracy: 0.9574 - val_top_3_accuracy: 0.9840 - lr: 1.0000e-05
# Epoch 30/30
# 908/908 [==============================] - ETA: 0s - loss: 0.2034 - categorical_accuracy: 0.9352 - top_2_accuracy: 0.9907 - top_3_accuracy: 0.9990
# Epoch 00030: val_top_3_accuracy did not improve from 0.98827
# 908/908 [==============================] - 46s 51ms/step - loss: 0.2034 - categorical_accuracy: 0.9352 - top_2_accuracy: 0.9907 - top_3_accuracy: 0.9990 - val_loss: 0.3495 - val_categorical_accuracy: 0.8913 - val_top_2_accuracy: 0.9574 - val_top_3_accuracy: 0.9851 - lr: 1.0000e-05

# %%
model.save("/content/drive/My Drive/Colab Notebooks/h5/mobilenet.h5")

# %%
model.metrics_names
# Out:
# ['loss', 'categorical_accuracy', 'top_2_accuracy', 'top_3_accuracy']

# %%
# Here the the last epoch will be used.

val_loss, val_cat_acc, val_top_2_acc, val_top_3_acc = \
model.evaluate_generator(test_batches, 
                        steps=len(df_val))

print('val_loss:', val_loss)
print('val_cat_acc:', val_cat_acc)
print('val_top_2_acc:', val_top_2_acc)
print('val_top_3_acc:', val_top_3_acc)
# Out:
# WARNING:tensorflow:From <ipython-input-40-d6f448ac5b89>:3: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# val_loss: 0.36139777302742004
# val_cat_acc: 0.8891258239746094
# val_top_2_acc: 0.9573560953140259
# val_top_3_acc: 0.9850746393203735

# %%
model.load_weights("/content/drive/My Drive/Colab Notebooks/h5/mobilenet.h5")
val_loss, val_cat_acc, val_top_2_acc, val_top_3_acc = \
model.evaluate_generator(test_batches, 
                        steps=len(df_val))

print('val_loss:', val_loss)
print('val_cat_acc:', val_cat_acc)
print('val_top_2_acc:', val_top_2_acc)
print('val_top_3_acc:', val_top_3_acc)
# Out:
# val_loss: 0.36139777302742004
# val_cat_acc: 0.8891258239746094
# val_top_2_acc: 0.9573560953140259
# val_top_3_acc: 0.9850746393203735

# %%
import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
train_top2_acc = history.history['top_2_accuracy']
val_top2_acc = history.history['val_top_2_accuracy']
train_top3_acc = history.history['top_3_accuracy']
val_top3_acc = history.history['val_top_3_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()

plt.plot(epochs, acc, 'bo', label='Training cat acc')
plt.plot(epochs, val_acc, 'b', label='Validation cat acc')
plt.title('Training and validation cat accuracy')
plt.legend()
plt.figure()


plt.plot(epochs, train_top2_acc, 'bo', label='Training top2 acc')
plt.plot(epochs, val_top2_acc, 'b', label='Validation top2 acc')
plt.title('Training and validation top2 accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, train_top3_acc, 'bo', label='Training top3 acc')
plt.plot(epochs, val_top3_acc, 'b', label='Validation top3 acc')
plt.title('Training and validation top3 accuracy')
plt.legend()


plt.show()

# %%
test_labels = test_batches.classes

# %%
# Print the label associated with each class
test_batches.class_indices
# Out:
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
predictions = model.predict_generator(test_batches, steps=len(df_val), verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-48-9962c3c7262c>:2: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 938/938 [==============================] - 10s 11ms/step

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
test_batches.class_indices
# Out:
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))
cm_plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'mel','nv', 'vasc']

plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[ 13   2   5   0   4   2   0]
#  [  1  21   6   0   2   0   0]
#  [  2   1  47   3   8  14   0]
#  [  0   0   0   3   1   2   0]
#  [  1   0   4   0  23  11   0]
#  [  1   2   9   2  23 710   4]
#  [  1   0   1   0   0   1   8]]

# %%
y_pred = np.argmax(predictions, axis=1)

# Get the labels of the test images.
y_true = test_batches.classes

# %%
from sklearn.metrics import classification_report

# Generate a classification report
report = classification_report(y_true, y_pred, target_names=cm_plot_labels)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.68      0.50      0.58        26
#          bcc       0.81      0.70      0.75        30
#          bkl       0.65      0.63      0.64        75
#           df       0.38      0.50      0.43         6
#          mel       0.38      0.59      0.46        39
#           nv       0.96      0.95      0.95       751
#         vasc       0.67      0.73      0.70        11
#
#     accuracy                           0.88       938
#    macro avg       0.65      0.66      0.64       938
# weighted avg       0.89      0.88      0.88       938
